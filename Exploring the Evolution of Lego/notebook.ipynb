# %% [markdown]
# ## # Introduction
# <p><img src="https://assets.datacamp.com/production/project_981/img/lego_unsplash.jpg" alt="A picture of Lego characters!"></p>
# <h3 id="letslookatlegosets">Let's look at Lego sets!</h3>
# <p>Lego is a household name across the world, supported by a diverse toy line, hit movies, and a series of successful video games. In this project, we are going to explore a key development in the history of Lego: the introduction of licensed sets such as Star Wars, Super Heroes, and Harry Potter.</p>
# <p>It may not be widely known, but Lego has had its share of ups and downs since its inception in the early 20th century. This includes a particularly rough period in the late 90s. As described in <a href="https://www.businessinsider.com/how-lego-made-a-huge-turnaround-2014-2?r=US&IR=T">this article</a>, Lego was only able to survive due to a successful internal brand (Bionicle) and the introduction of its first licensed series: Star Wars. In the instructions panel are the two questions you will need to answer to complete this project.</p>
# <p>Before diving into our analysis though, let's become familiar with the two datasets that will help you with this project:<br><br></p>
# <div style="background-color: #ebf4f7; color: #595959; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/lego_sets.csv</b></div>
# <ul>
#     <li><b>set_num:</b> A code that is unique to each set in the dataset. <b><i>This column is critical, and a missing value indicates the set is a duplicate or invalid!</i></b></li>
#     <li><b>set_name:</b> A name for every set in the dataset (note that this can be the same for different sets).</li>
#     <li><b>year:</b> The date the set was released.</li>
#     <li><b>num_parts:</b> The number of parts contained in the set.<b><i> This column is not central to our analyses, so missing values are acceptable.</i></b></li>
#         <li><b>theme_name:</b> The name of the sub-theme of the set.</li>
#     <li><b>parent_theme:</b> The name of the parent theme the set belongs to. Matches the `name` column of the `parent_themes` csv file.</li>
# </ul>
#
# <div style="font-size:20px"><b>datasets/parent_themes.csv</b></div>
# <ul>
#     <li><b>id:</b> A code that is unique to every theme.</li>
#     <li><b>name:</b> The name of the parent theme.</li>
#     <li><b>is_licensed:</b> A Boolean column specifying whether the theme is a licensed theme.</li>
# </ul>
#     </div>
# <p>From here on out, it will be your task to explore and manipulate the existing data until you are able to answer the two questions described in the instructions panel. Feel free to add as many cells as necessary. Finally, remember that you are only tested on your answer, not on the methods you use to arrive at the answer!</p>
# <p><em><strong>Note:</strong> If you haven't completed a DataCamp project before you should check out the <a href="https://projects.datacamp.com/projects/33">Intro to Projects</a> first to learn about the interface. In this project, you also need to know your way around <code>pandas</code> DataFrames and it's recommended that you take a look at the course <a href="https://www.datacamp.com/courses/data-manipulation-with-pandas">Data Manipulation with pandas</a>.</em></p>

# %%
# Use this cell to begin your analyses, and add as many cells as you would like!
import pandas as pd 
df = pd.read_csv('datasets/lego_sets.csv')
df
# Out:
#       set_num                        name  year  num_parts    theme_name  \
# 0        00-1             Weetabix Castle  1970      471.0        Castle
# 1      0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2      0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3      0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4      0013-1          Space Mini-Figures  1979       12.0  Supplemental
# ...       ...                         ...   ...        ...           ...
# 11981     NaN                         NaN  2014        NaN           NaN
# 11982     NaN                         NaN  2006        NaN           NaN
# 11983     NaN                         NaN  2017        NaN           NaN
# 11984     NaN                         NaN  2017        8.0           NaN
# 11985     NaN                         NaN  2003        NaN           NaN
#
#        parent_theme
# 0          Legoland
# 1              Town
# 2            Castle
# 3             Space
# 4             Space
# ...             ...
# 11981     Minecraft
# 11982  Super Heroes
# 11983     Minecraft
# 11984  Super Heroes
# 11985  Harry Potter
#
# [11986 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# 44

# %%
df.drop_duplicates()
# Out:
#       set_num                        name  year  num_parts    theme_name  \
# 0        00-1             Weetabix Castle  1970      471.0        Castle
# 1      0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2      0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3      0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4      0013-1          Space Mini-Figures  1979       12.0  Supplemental
# ...       ...                         ...   ...        ...           ...
# 11975     NaN                         NaN  2010      442.0           NaN
# 11976     NaN                         NaN  2012       44.0           NaN
# 11978     NaN                         NaN  2004      485.0           NaN
# 11979     NaN                         NaN  2016      561.0           NaN
# 11985     NaN                         NaN  2003        NaN           NaN
#
#        parent_theme
# 0          Legoland
# 1              Town
# 2            Castle
# 3             Space
# 4             Space
# ...             ...
# 11975  Harry Potter
# 11976  Super Heroes
# 11978  Super Heroes
# 11979  Super Heroes
# 11985  Harry Potter
#
# [11942 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# set_num          153
# name             153
# year               0
# num_parts       5060
# theme_name       153
# parent_theme       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11986 entries, 0 to 11985
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   set_num       11833 non-null  object
#  1   name          11833 non-null  object
#  2   year          11986 non-null  int64
#  3   num_parts     6926 non-null   float64
#  4   theme_name    11833 non-null  object
#  5   parent_theme  11986 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 562.0+ KB

# %%
df.describe()
# Out:
#                year    num_parts
# count  11986.000000  6926.000000
# mean    2002.304772   163.782558
# std       13.471680   334.206873
# min     1950.000000    -1.000000
# 25%     1997.000000    10.250000
# 50%     2006.000000    46.000000
# 75%     2013.000000   173.000000
# max     2017.000000  5922.000000

# %%
df['num_parts'].mean()
# Out:
# 163.78255847531042

# %%
df.dropna(subset=['name'],inplace = True)
df.isna().sum()
# Out:
# set_num            0
# name               0
# year               0
# num_parts       4998
# theme_name         0
# parent_theme       0
# dtype: int64

# %%
df['num_parts'].fillna(df['num_parts'].mean(),inplace = True)
df.isna().sum()
# Out:
# set_num         0
# name            0
# year            0
# num_parts       0
# theme_name      0
# parent_theme    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11833 entries, 0 to 11832
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   set_num       11833 non-null  object
#  1   name          11833 non-null  object
#  2   year          11833 non-null  int64
#  3   num_parts     11833 non-null  float64
#  4   theme_name    11833 non-null  object
#  5   parent_theme  11833 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 647.1+ KB

# %%
df.columns
# Out:
# Index(['set_num', 'name', 'year', 'num_parts', 'theme_name', 'parent_theme'], dtype='object')

# %%
the_force = df[df['theme_name'] == 'Star Wars']['set_num']
the_force
# Out:
# 44           10018-1
# 638          11912-1
# 1886       2853835-1
# 2013         30058-1
# 2014         30059-1
#             ...
# 11761     SW911617-1
# 11764     SW911722-1
# 11767     SW911725-1
# 11787    TRUFALCON-1
# 11802     TRUXWING-2
# Name: set_num, Length: 211, dtype: object

# %%
parent_themes = pd.read_csv('datasets/parent_themes.csv')
parent_themes.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %%
lego_joined = df.merge(parent_themes,how='left',left_on = 'parent_theme',right_on = 'name',suffixes=('','_y'))
lego_joined.head()
# Out:
#   set_num                        name  year   num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970  471.000000        Castle
# 1  0011-2           Town Mini-Figures  1978  162.149086  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987  162.149086  Lion Knights
# 3  0012-1          Space Mini-Figures  1979   12.000000  Supplemental
# 4  0013-1          Space Mini-Figures  1979   12.000000  Supplemental
#
#   parent_theme   id    name_y  is_licensed
# 0     Legoland  411  Legoland        False
# 1         Town   50      Town        False
# 2       Castle  186    Castle        False
# 3        Space  126     Space        False
# 4        Space  126     Space        False

# %%
all_sets = len(lego_joined[lego_joined['is_licensed']==True])
all_sets
# Out:
# 1179

# %%
star_wars_licensed = lego_joined[(lego_joined['parent_theme'] == 'Star Wars') & (lego_joined['is_licensed'] == True)]

# %%
len(star_wars_licensed)
# Out:
# 609

# %%
ratio = len(star_wars_licensed)/all_sets
the_force = int(ratio*100)
print(the_force)
# Out:
# 51

# %%
licensed_set = lego_joined[lego_joined['is_licensed']==True]
licensed_set
# Out:
#        set_num                                     name  year    num_parts  \
# 44     10018-1                               Darth Maul  2001  1868.000000
# 45     10019-1              Rebel Blockade Runner - UCS  2001   162.149086
# 54     10026-1                  Naboo Starfighter - UCS  2002   162.149086
# 57     10030-1            Imperial Star Destroyer - UCS  2002  3115.000000
# 95     10075-1                   Spider-Man Action Pack  2002    25.000000
# ...        ...                                      ...   ...          ...
# 11811    VP-12       Star Wars Co-Pack of 7121 and 7151  2000     2.000000
# 11816     VP-2       Star Wars Co-Pack of 7110 and 7144  2001     2.000000
# 11817     VP-3       Star Wars Co-Pack of 7131 and 7151  2000     2.000000
# 11818     VP-4  Star Wars Co-Pack of 7101 7111 and 7171  2000     3.000000
# 11822     VP-8       Star Wars Co-Pack of 7130 and 7150  2000   162.149086
#
#                     theme_name  parent_theme   id        name_y  is_licensed
# 44                   Star Wars     Star Wars  158     Star Wars         True
# 45     Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 54         Star Wars Episode 1     Star Wars  158     Star Wars         True
# 57     Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 95                  Spider-Man  Super Heroes  482  Super Heroes         True
# ...                        ...           ...  ...           ...          ...
# 11811      Star Wars Episode 1     Star Wars  158     Star Wars         True
# 11816  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 11817      Star Wars Episode 1     Star Wars  158     Star Wars         True
# 11818      Star Wars Episode 1     Star Wars  158     Star Wars         True
# 11822  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
#
# [1179 rows x 9 columns]

# %%
licensed_pivot = licensed_set.pivot_table(index='year',columns='parent_theme',values='set_num',aggfunc='count')
licensed_pivot
# Out:
# parent_theme  Angry Birds  Avatar  Ben 10  Cars  Disney  Disney Princess  \
# year
# 1999                  NaN     NaN     NaN   NaN     NaN              NaN
# 2000                  NaN     NaN     NaN   NaN     NaN              NaN
# 2001                  NaN     NaN     NaN   NaN     NaN              NaN
# 2002                  NaN     NaN     NaN   NaN     NaN              NaN
# 2003                  NaN     NaN     NaN   NaN     NaN              NaN
# 2004                  NaN     NaN     NaN   NaN     NaN              NaN
# 2005                  NaN     NaN     NaN   NaN     NaN              NaN
# 2006                  NaN     2.0     NaN   NaN     NaN              NaN
# 2007                  NaN     NaN     NaN   NaN     NaN              NaN
# 2008                  NaN     NaN     NaN   NaN     NaN              NaN
# 2009                  NaN     NaN     NaN   NaN     NaN              NaN
# 2010                  NaN     NaN     6.0   NaN     NaN              NaN
# 2011                  NaN     NaN     NaN  18.0     NaN              NaN
# 2012                  NaN     NaN     NaN   9.0     NaN              NaN
# 2013                  NaN     NaN     NaN   NaN     NaN              NaN
# 2014                  NaN     NaN     NaN   NaN     NaN              8.0
# 2015                  NaN     NaN     NaN   NaN     NaN              4.0
# 2016                  6.0     NaN     NaN   NaN     1.0             11.0
# 2017                  NaN     NaN     NaN   NaN     NaN              6.0
#
# parent_theme  Disney's Mickey Mouse  Ghostbusters  Harry Potter  \
# year
# 1999                            NaN           NaN           NaN
# 2000                            5.0           NaN           NaN
# 2001                            NaN           NaN          11.0
# 2002                            NaN           NaN          19.0
# 2003                            NaN           NaN           3.0
# 2004                            NaN           NaN          14.0
# 2005                            1.0           NaN           5.0
# 2006                            NaN           NaN           NaN
# 2007                            NaN           NaN           1.0
# 2008                            NaN           NaN           NaN
# 2009                            NaN           NaN           NaN
# 2010                            NaN           NaN           6.0
# 2011                            NaN           NaN           8.0
# 2012                            NaN           NaN           NaN
# 2013                            NaN           NaN           NaN
# 2014                            NaN           NaN           NaN
# 2015                            NaN           NaN           NaN
# 2016                            NaN           1.0           NaN
# 2017                            NaN           NaN           NaN
#
# parent_theme  Indiana Jones  ...  Pirates of the Caribbean  Prince of Persia  \
# year                         ...
# 1999                    NaN  ...                       NaN               NaN
# 2000                    NaN  ...                       NaN               NaN
# 2001                    NaN  ...                       NaN               NaN
# 2002                    NaN  ...                       NaN               NaN
# 2003                    NaN  ...                       NaN               NaN
# 2004                    NaN  ...                       NaN               NaN
# 2005                    NaN  ...                       NaN               NaN
# 2006                    NaN  ...                       NaN               NaN
# 2007                    NaN  ...                       NaN               NaN
# 2008                   12.0  ...                       NaN               NaN
# 2009                    7.0  ...                       NaN               NaN
# 2010                    NaN  ...                       NaN               6.0
# 2011                    NaN  ...                      16.0               NaN
# 2012                    NaN  ...                       NaN               NaN
# 2013                    NaN  ...                       NaN               NaN
# 2014                    NaN  ...                       NaN               NaN
# 2015                    NaN  ...                       NaN               NaN
# 2016                    NaN  ...                       NaN               NaN
# 2017                    NaN  ...                       1.0               NaN
#
# parent_theme  Scooby-Doo  SpongeBob SquarePants  Star Wars  Super Heroes  \
# year
# 1999                 NaN                    NaN       13.0           NaN
# 2000                 NaN                    NaN       26.0           NaN
# 2001                 NaN                    NaN       14.0           NaN
# 2002                 NaN                    NaN       28.0           3.0
# 2003                 NaN                    NaN       32.0           5.0
# 2004                 NaN                    NaN       20.0           6.0
# 2005                 NaN                    NaN       28.0           1.0
# 2006                 NaN                    3.0       11.0           8.0
# 2007                 NaN                    2.0       16.0           2.0
# 2008                 NaN                    3.0       23.0           5.0
# 2009                 NaN                    2.0       39.0           NaN
# 2010                 NaN                    NaN       30.0           NaN
# 2011                 NaN                    2.0       32.0           5.0
# 2012                 NaN                    2.0       43.0          32.0
# 2013                 NaN                    NaN       35.0          19.0
# 2014                 NaN                    NaN       45.0          23.0
# 2015                 5.0                    NaN       58.0          28.0
# 2016                 1.0                    NaN       61.0          33.0
# 2017                 NaN                    NaN       55.0          72.0
#
# parent_theme  Teenage Mutant Ninja Turtles  The Hobbit and Lord of the Rings  \
# year
# 1999                                   NaN                               NaN
# 2000                                   NaN                               NaN
# 2001                                   NaN                               NaN
# 2002                                   NaN                               NaN
# 2003                                   NaN                               NaN
# 2004                                   NaN                               NaN
# 2005                                   NaN                               NaN
# 2006                                   NaN                               NaN
# 2007                                   NaN                               NaN
# 2008                                   NaN                               NaN
# 2009                                   NaN                               NaN
# 2010                                   NaN                               NaN
# 2011                                   NaN                               NaN
# 2012                                   2.0                              20.0
# 2013                                   9.0                              13.0
# 2014                                  10.0                               6.0
# 2015                                   NaN                               1.0
# 2016                                   NaN                               NaN
# 2017                                   NaN                               NaN
#
# parent_theme  The Lone Ranger  Toy Story
# year
# 1999                      NaN        NaN
# 2000                      NaN        NaN
# 2001                      NaN        NaN
# 2002                      NaN        NaN
# 2003                      NaN        NaN
# 2004                      NaN        NaN
# 2005                      NaN        NaN
# 2006                      NaN        NaN
# 2007                      NaN        NaN
# 2008                      NaN        NaN
# 2009                      NaN        NaN
# 2010                      NaN       15.0
# 2011                      NaN        NaN
# 2012                      NaN        NaN
# 2013                      8.0        NaN
# 2014                      NaN        NaN
# 2015                      NaN        NaN
# 2016                      NaN        NaN
# 2017                      NaN        NaN
#
# [19 rows x 22 columns]

# %%
yearly_max = licensed_pivot.max(axis='columns')
yearly_max
# Out:
# year
# 1999    13.0
# 2000    26.0
# 2001    14.0
# 2002    28.0
# 2003    32.0
# 2004    20.0
# 2005    28.0
# 2006    11.0
# 2007    16.0
# 2008    23.0
# 2009    39.0
# 2010    30.0
# 2011    32.0
# 2012    43.0
# 2013    35.0
# 2014    45.0
# 2015    58.0
# 2016    61.0
# 2017    72.0
# dtype: float64

# %%
filtered_max = licensed_pivot[licensed_pivot['Star Wars']<yearly_max]
filtered_max
# Out:
# parent_theme  Angry Birds  Avatar  Ben 10  Cars  Disney  Disney Princess  \
# year
# 2017                  NaN     NaN     NaN   NaN     NaN              6.0
#
# parent_theme  Disney's Mickey Mouse  Ghostbusters  Harry Potter  \
# year
# 2017                            NaN           NaN           NaN
#
# parent_theme  Indiana Jones  ...  Pirates of the Caribbean  Prince of Persia  \
# year                         ...
# 2017                    NaN  ...                       1.0               NaN
#
# parent_theme  Scooby-Doo  SpongeBob SquarePants  Star Wars  Super Heroes  \
# year
# 2017                 NaN                    NaN       55.0          72.0
#
# parent_theme  Teenage Mutant Ninja Turtles  The Hobbit and Lord of the Rings  \
# year
# 2017                                   NaN                               NaN
#
# parent_theme  The Lone Ranger  Toy Story
# year
# 2017                      NaN        NaN
#
# [1 rows x 22 columns]

# %%
most_popular_sets = licensed_set.groupby('year')['parent_theme'].agg(pd.)
